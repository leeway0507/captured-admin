# %%
import aiofiles
import json
from itertools import chain
import pandas as pd

path = './product_card_list.json'
async with aiofiles.open(path, "r", encoding="utf-8") as f:
    v = await f.read()
    v = v.replace('null', 'None').replace('true', 'True').replace('false', 'False')
    v = eval(v)


pd.DataFrame(v)
# Out:
#                                                   0   \
# 0  {'shop_product_name': 'a-p-c-candle-no-2-green...
# 1  {'shop_product_name': 'a-p-c-candle-no-2-green...
# 2  {'shop_product_name': 'and-wander-reflective-l...
#
#                                                   1   \
# 0  {'shop_product_name': 'a-p-c-candle-no-3-toumb...
# 1  {'shop_product_name': 'a-p-c-candle-no-3-toumb...
# 2  {'shop_product_name': 'and-wander-mountain-cam...
#
#                                                   2   \
# 0  {'shop_product_name': 'a-p-c-candle-no-4-orang...
# 1  {'shop_product_name': 'a-p-c-candle-no-4-orang...
# 2  {'shop_product_name': 'and-wander-mountain-t-s...
#
#                                                   3   \
# 0  {'shop_product_name': 'a-p-c-candle-no-5-feuil...
# 1  {'shop_product_name': 'a-p-c-candle-no-5-feuil...
# 2  {'shop_product_name': 'and-wander-in-the-mount...
#
#                                                   4   \
# 0  {'shop_product_name': 'a-p-c-candle-no-6-incen...
# 1  {'shop_product_name': 'a-p-c-candle-no-6-incen...
# 2  {'shop_product_name': 'and-wander-in-the-mount...
#
#                                                   5   \
# 0  {'shop_product_name': 'a-p-c-small-candle-set-...
# 1  {'shop_product_name': 'a-p-c-small-candle-set-...
# 2  {'shop_product_name': 'and-wander-in-the-mount...
#
#                                                   6   \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'and-wander-big-logo-t-s...
#
#                                                   7   \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'and-wander-big-logo-t-s...
#
#                                                   8   \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'and-wander-big-logo-t-s...
#
#                                                   9   ...  \
# 0                                               None  ...
# 1                                               None  ...
# 2  {'shop_product_name': 'and-wander-big-logo-t-s...  ...
#
#                                                   60  \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'adidas-terrex-x-and-wan...
#
#                                                   61  \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'adidas-terrex-x-and-wan...
#
#                                                   62  \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'adidas-terrex-x-and-wan...
#
#                                                   63  \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'adidas-terrex-x-and-wan...
#
#                                                   64  \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'adidas-terrex-x-and-wan...
#
#                                                   65  \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'adidas-terrex-x-and-wan...
#
#                                                   66  \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'adidas-terrex-x-and-wan...
#
#                                                   67  \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'adidas-terrex-x-and-wan...
#
#                                                   68  \
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'adidas-terrex-x-and-wan...
#
#                                                   69
# 0                                               None
# 1                                               None
# 2  {'shop_product_name': 'adidas-terrex-x-and-wan...
#
# [3 rows x 70 columns]

# %%
pd.DataFrame(list(chain(*v))).drop_duplicates().
# Out:
#                                     shop_product_name  \
# 0    a-p-c-candle-no-2-green-jasmine-ybzaa-m84001-vab
# 1          a-p-c-candle-no-3-toumbac-ybzaa-m84001-vac
# 2   a-p-c-candle-no-4-orange-blossom-ybzaa-m84001-vad
# 3   a-p-c-candle-no-5-feuille-de-figuier-ybzaa-m84...
# 4          a-p-c-candle-no-6-incense-ybzaa-m84001-vag
# ..                                                ...
# 77  adidas-terrex-x-and-wander-shorts-wonder-taupe...
# 78  adidas-terrex-x-and-wander-cold-rdy-wool-socks...
# 79  adidas-terrex-x-and-wander-cold-rdy-wool-socks...
# 80  adidas-terrex-x-and-wander-bucket-hat-black-mu...
# 81  adidas-terrex-x-and-wander-bucket-hat-linen-gr...
#
#                                  shop_product_img_url  \
# 0   https://www.consortium.co.uk/media/catalog/pro...
# 1   https://www.consortium.co.uk/media/catalog/pro...
# 2   https://www.consortium.co.uk/media/catalog/pro...
# 3   https://www.consortium.co.uk/media/catalog/pro...
# 4   https://www.consortium.co.uk/media/catalog/pro...
# ..                                                ...
# 77  https://www.consortium.co.uk/media/catalog/pro...
# 78  https://www.consortium.co.uk/media/catalog/pro...
# 79  https://www.consortium.co.uk/media/catalog/pro...
# 80  https://www.consortium.co.uk/media/catalog/pro...
# 81  https://www.consortium.co.uk/media/catalog/pro...
#
#                                           product_url   shop_name  \
# 0   https://www.consortium.co.uk/a-p-c-candle-no-2...  consortium
# 1   https://www.consortium.co.uk/a-p-c-candle-no-3...  consortium
# 2   https://www.consortium.co.uk/a-p-c-candle-no-4...  consortium
# 3   https://www.consortium.co.uk/a-p-c-candle-no-5...  consortium
# 4   https://www.consortium.co.uk/a-p-c-candle-no-6...  consortium
# ..                                                ...         ...
# 77  https://www.consortium.co.uk/adidas-terrex-x-a...  consortium
# 78  https://www.consortium.co.uk/adidas-terrex-x-a...  consortium
# 79  https://www.consortium.co.uk/adidas-terrex-x-a...  consortium
# 80  https://www.consortium.co.uk/adidas-terrex-x-a...  consortium
# 81  https://www.consortium.co.uk/adidas-terrex-x-a...  consortium
#
#          brand_name        product_id   search_keyword kor_price us_price  \
# 0   a.p.c. homeware  ybzaa-m84001-vab  a.p.c. homeware      None     None
# 1   a.p.c. homeware  ybzaa-m84001-vac  a.p.c. homeware      None     None
# 2   a.p.c. homeware  ybzaa-m84001-vad  a.p.c. homeware      None     None
# 3   a.p.c. homeware  ybzaa-m84001-vae  a.p.c. homeware      None     None
# 4   a.p.c. homeware  ybzaa-m84001-vag  a.p.c. homeware      None     None
# ..              ...               ...              ...       ...      ...
# 77       and wander            hr7135       and wander      None     None
# 78       and wander            hm3861       and wander      None     None
# 79       and wander            hm3860       and wander      None     None
# 80       and wander            hm3862       and wander      None     None
# 81       and wander            hm3863       and wander      None     None
#
#    original_price_currency original_price  sold_out update_at
# 0                     None         £39.99     False      None
# 1                     None         £39.99     False      None
# 2                     None         £39.99     False      None
# 3                     None         £39.99     False      None
# 4                     None         £39.99     False      None
# ..                     ...            ...       ...       ...
# 77                    None         £69.99     False      None
# 78                    None         £24.99     False      None
# 79                    None         £24.99     False      None
# 80                    None         £29.99     False      None
# 81                    None         £29.99     False      None
#
# [76 rows x 13 columns]

# %%
import pandas as pd

# %%
pd.read_parquet("./shop_scrap_page_size_data.parquet.gzip")
# Out:
#     shop_product_card_id shop_product_size kor_product_size  available  \
# 0                   4924                 S                S       True
# 1                   4924                 M                M       True
# 2                   4924                 L                L       True
# 3                   4945                 M                M       True
# 4                   4945                 L                L       True
# 5                   4945                XL               XL       True
# 6                   4931          ONE SIZE         ONE SIZE       True
# 7                   4946                 S                S       True
# 8                   4946                XL               XL       True
# 9                   5641                 M                M       True
# 10                  4942                 S                S       True
# 11                  4942                 M                M       True
# ...

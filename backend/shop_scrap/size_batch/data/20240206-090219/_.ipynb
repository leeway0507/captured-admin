# %%
x = pd.read_parquet("./batch_prod_size_data.parquet.gzip")

# %%
x.drop(x.index[537], inplace=True)

# %%
x.to_parquet("./batch_prod_size_data.parquet.gzip")

# %%
x[x['sku'] ==138].iloc[-1]
# Out:
# sku                           138
# size                          290
# updated_at    2024-02-06 09:04:10
# available                       1
# Name: 536, dtype: object

# %%
x.to_json("test.json",orient="records")

# %%
x = pd.read_parquet("./shop_scrap_page_size_data.parquet.gzip")

# %%
x
# Out:
#      shop_product_card_id shop_product_size kor_product_size  available  \
# 0                    1388                XS               XS       True
# 1                    1388            Medium                M       True
# 2                    1388             Large                L       True
# 3                    6535                 L                L       True
# 4                    6535                XL               XL       True
# ..                    ...               ...              ...        ...
# 902                 11990           X-Large               XL       True
# 903                 11999             Small                S       True
# 904                 11999            Medium                M       True
# 905                 11999             Large                L       True
# 906                 11999           X-Large               XL       True
#
#              updated_at  product_id original_price
# 0   2024-02-06 09:04:10  22835-NENA        £119.99
# ...

# %%
x = pd.read_parquet("./batch_shop_size_data.parquet.gzip")

# %%
x[x["shop_product_card_id"] ==9816]
# Out:
#      shop_product_size_id  shop_product_card_id shop_product_size  \
# 636                 14361                  9816            UK 8.5
# 637                 14362                  9816              UK 9
# 638                 14363                  9816           UK 10.5
#
#     kor_product_size  available          updated_at
# 636              270       True 2024-02-06 09:04:10
# 637              275       True 2024-02-06 09:04:10
# 638              290       True 2024-02-06 09:04:10

# %%
# 11905
x = pd.read_parquet("./batch_prod_card_data.parquet.gzip")
y = pd.read_parquet("./batch_shop_card_data.parquet.gzip")

# %%
y[y["shop_product_card_id"] == 11905]
# Out:
#      shop_product_card_id                                  shop_product_name  \
# 187                 11905  adidas handball spezial - night cargo & tribe ...
#
#        shop_name brand_name product_id  \
# 187  endclothing     adidas     EF5748
#
#                                   shop_product_img_url  \
# 187  https://media.endclothing.com/media/f_auto,q_a...
#
#                                            product_url  kor_price  us_price  \
# 187  https://www.endclothing.com/kr/adidas-handball...     129000     96.53
#
#     original_price_currency  original_price  coupon  sold_out  candidate  \
# 187                     KRW        128775.0     0.0      True          2
#
#              updated_at
# 187 2024-02-05 14:00:45

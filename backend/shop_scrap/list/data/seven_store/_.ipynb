# %%
import pandas as pd

# %%
pd.read_parquet("./20240122-124740.parquet.gzip")
# Out:
#    shop_product_card_id                                  shop_product_name  \
# 0                  None            adidashandball spezial sneaker - 132222
# 1                  None  adidas x craig greenstan smith full boost snea...
# 2                  None  adidasx cali dewitt campus 80s sneaker  - 4090347
# 3                  None            adidashandball spezial sneaker - 132220
# 4                  None                 adidascountry og sneaker - 4089266
# 5                  None           adidashandball spezial sneaker - 4096626
# 6                  None               adidasgazelle bold sneaker - 4096493
# 7                  None            adidasgazelle indoor sneaker  - 4089666
# 8                  None                   adidassamba og sneaker - 4089044
# 9                  None                    adidasbermuda sneaker - 4092414
# 10                 None                   adidassamba og sneaker - 4092416
# ...

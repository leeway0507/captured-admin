# %%
import pandas as pd

# %%
pd.read_parquet("./20240201-143942.parquet.gzip")
# Out:
#     shop_product_card_id                                  shop_product_name  \
# 0                   None  and wander pertex shield rain jacket 574321100...
# 1                   None  jacquemus le cargo croissant 236pa055-1485 dar...
# 2                   None                  acne studios kimothy b60242 beige
# 3                   None  maison margiela pullover si1ha0005 s17784 dark...
# 4                   None  comme des garçons shirt crochet lace ptrn 2 fk...
# ..                   ...                                                ...
# 615                 None  acne studios face - kalon new face c60042 ligh...
# 616                 None  awake ny king logo twill coaches jacket awk-sp...
# 617                 None  adidas originals supernova cushion 7 - maggre/...
# 618                 None  ami - alexandre mattiussi elasticated bermuda ...
# 619                 None      erl unisex degrade beanie knit erl06k056 blue
#
# ...

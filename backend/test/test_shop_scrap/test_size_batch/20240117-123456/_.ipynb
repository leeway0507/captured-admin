# %%
import pandas as pd

# %%
pd.read_parquet("./batch_prod_card_data.parquet.gzip")
# Out:
#     sku             brand   kor_brand  \
# 0     1         patagonia       파타고니아
# 1     2         patagonia        None
# 2     3         patagonia       파타고니아
# 3     4  adidas originals  아디다스 오리지널스
# 4     5  adidas originals  아디다스 오리지널스
# 5     6  adidas originals        None
# 6     8  adidas originals  아디다스 오리지널스
# 7     9        human made        None
# 8    10        human made        None
# 9    11        human made        None
# 10   13        human made        None
# 11   14  adidas originals  아디다스 오리지널스
# 12   15  adidas originals  아디다스 오리지널스
# 13   16        our legacy       아워레거시
# 14   17         patagonia       파타고니아
# 15   18  adidas originals  아디다스 오리지널스
# 16   19  clarks originals         클락스
# 17   20  clarks originals         클락스
# 18   21  clarks originals         클락스
# 19   22  adidas originals  아디다스 오리지널스
# 20   23  adidas originals  아디다스 오리지널스
# 21   24  adidas originals  아디다스 오리지널스
# 22   25  adidas originals  아디다스 오리지널스
# ...

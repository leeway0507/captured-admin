# %%
import pandas as pd

# %%
pd.read_parquet("./20240109-162104-size.parquet.gzip")
# Out:
#      shop_product_card_id       shop_product_size kor_product_size  available  \
# 0                    1204      XS - EU 44 - JPN 1               XS       True
# 1                    1204  Medium - EU 48 - JPN 3                M       True
# 2                    1204   Large - EU 50 - JPN 4                L       True
# 3                     116                    UK 9              275       True
# 4                     116                  UK 9.5              280       True
# ..                    ...                     ...              ...        ...
# 313                  4649                      XL               XL       True
# 314                  4650                       S                S       True
# 315                  4650                       M                M       True
# 316                  4650                       L                L       True
# 317                  4650                      XL               XL       True
#
# ...

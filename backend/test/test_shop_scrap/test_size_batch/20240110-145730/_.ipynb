# %%
import pandas as pd

# %%
x = pd.read_parquet("./test_id_map.parquet")
x.sort_values(by="sku")
# Out:
#     product_id  shop_product_card_id  sku
# 30   26260-BLK                  1411    1
# 20   25450-OAT                  1201    3
# 18      GM4256                   619    4
# 5       IG5003                   146    5
# 2       H06259                   135    7
# 3       H06259                  2185    7
# 0       DB3021                   118    8
# 1       DB3021                  2182    8
# 31    HM2CS005                  2335   12
# 12      IE7426                   178   14
# 13      IE7426                  2188   14
# 10      IE7427                   177   15
# 11      IE7427                  2187   15
# 28     W4236CM                  1355   16
# 25  26210-TIDB                  1214   17
# 16      HQ6901                   353   18
# 38    26171744                  4097   19
# 37    26171491                  4096   20
# 36    26155517                  4073   21
# 35      IE0876                  3347   22
# 34      IE2948                  3346   23
# ...

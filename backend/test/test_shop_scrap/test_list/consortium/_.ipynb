# %%
import pandas as pd

# %%
pd.read_parquet("./20240107-215804.parquet.gzip")
# Out:
#    shop_product_card_id                                  shop_product_name  \
# 0                  None   a-p-c-new-raymond-t-shirt-lilac-coezc-h26247-had
# 1                  None  a-p-c-x-liberty-camo-t-shirt-heathered-light-g...
# 2                  None  a-p-c-x-gimme-five-samy-t-shirt-interaction-co...
# 3                  None  a-p-c-cabourg-boxer-shorts-white-cobmb-h18024-aab
# 4                  None  a-p-c-x-liberty-dragon-t-shirt-white-cofdw-h26...
# 5                  None     a-p-c-vincent-shirt-navy-blue-coeut-h12426-iaj
# 6                  None  a-p-c-pablo-pullover-sweater-vert-wvaxy-h23964...
# 7                  None  a-p-c-x-liberty-bob-bucket-hat-marine-paaff-m2...
# 8                  None  a-p-c-bellini-logo-short-sleeve-shirt-blue-lia...
# 9                  None  a-p-c-pablo-pullover-sweater-dark-navy-wvaxy-h...
# 10                 None       a-p-c-toni-jumper-dark-navy-wvbam-h23033-iak
# ...

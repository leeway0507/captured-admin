# %%
import pandas as pd

pd.read_parquet("./20240107-195355-buy_and_sell.parquet.gzip")
# Out:
#      kream_id kream_product_size     buy    sell          updated_at
# 0       82075                  S       0  650000 2024-01-07 19:59:25
# 1       82075                  L  300000       0 2024-01-07 19:59:25
# 2       84964                 XS       0  435000 2024-01-07 19:59:25
# 3       84964                  S  160000       0 2024-01-07 19:59:25
# 4       84964                  M  320000  409000 2024-01-07 19:59:25
# ..        ...                ...     ...     ...                 ...
# 477     90454                  M  205000  243000 2024-01-07 19:59:25
# 478     90454                  L  250000  289000 2024-01-07 19:59:25
# 479     90454                 XL  267000  284000 2024-01-07 19:59:25
# 480     90454                XXL  250000  311000 2024-01-07 19:59:25
# 481     90454               XXXL  260000  319000 2024-01-07 19:59:25
#
# [482 rows x 5 columns]

# %%
pd.read_parquet("./20240107-195355-product_bridge.parquet.gzip")
# Out:
#      product_id  kream_id
# 0      NJ1DN80L     82075
# 1      NJ1DN50K     84964
# 2      NJ1DN82B     84409
# 3      NJ1DN82A     82702
# 4      NV3NP55A    187477
# ..          ...       ...
# 95  NF0A7WX4128     65385
# 96  NF0A3C8DLE4     48726
# 97  NF0A7WX4JK3     65384
# 98  NF0A3C8D6S2     93545
# 99  NF0A3JQQLE4     90454
#
# [100 rows x 2 columns]

# %%
pd.read_parquet("./20240107-195355-product_detail.parquet.gzip")
# Out:
#     kream_id                              kream_product_img_url  \
# 0      82075  https://kream-phinf.pstatic.net/MjAyMzAxMTZfNj...
# 1      84964  https://kream-phinf.pstatic.net/MjAyMjExMTBfMj...
# 2      84409  https://kream-phinf.pstatic.net/MjAyMjExMDhfMT...
# 3      82702  https://kream-phinf.pstatic.net/MjAyMjExMDNfMj...
# 4     187477  https://kream-phinf.pstatic.net/MjAyMzEwMTZfMT...
# ..       ...                                                ...
# 95     65385  https://kream-phinf.pstatic.net/MjAyMjA2MTRfMT...
# 96     48726  https://kream-phinf.pstatic.net/MjAyMjExMDNfMj...
# 97     65384  https://kream-phinf.pstatic.net/MjAyMjExMDRfMT...
# 98     93545  https://kream-phinf.pstatic.net/MjAyMzAxMDVfMT...
# 99     90454  https://kream-phinf.pstatic.net/MjAyMjEyMTZfMT...
#
#                                    kream_product_name      brand_name  \
# 0    (w) the north face white label novelty nuptse...  the north face
# ...

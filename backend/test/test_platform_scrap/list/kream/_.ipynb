# %%
import pandas as pd 

pd.read_parquet("./")
# Out:
#     kream_id                              kream_product_img_url  \
# 0      48860  https://kream-phinf.pstatic.net/MjAyMjExMDNfMT...
# 1      77585  https://kream-phinf.pstatic.net/MjAyMjExMDNfOT...
# 2     169993  https://kream-phinf.pstatic.net/MjAyMzA5MDFfOD...
# 3      50142  https://kream-phinf.pstatic.net/MjAyMjEyMjFfMj...
# 4     140970  https://kream-phinf.pstatic.net/MjAyMzA2MjZfMT...
# ..       ...                                                ...
# 95     86579  https://kream-phinf.pstatic.net/MjAyMjExMjNfMj...
# 96    212454  https://kream-phinf.pstatic.net/MjAyMzEyMDFfMi...
# 97    175668  https://kream-phinf.pstatic.net/MjAyMzA5MTRfMj...
# 98    206385  https://kream-phinf.pstatic.net/MjAyMzExMjNfOT...
# 99    178682  https://kream-phinf.pstatic.net/MjAyMzA5MjFfMT...
#
#                                    kream_product_name      brand_name  \
# 0         the north face 1996 eco nuptse jacket black  the north face
# ...

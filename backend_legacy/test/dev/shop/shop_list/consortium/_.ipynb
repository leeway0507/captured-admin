# %%
import pandas as pd

pd.read_parquet("./20240103-181428.parquet.gzip")
# Out:
#    shop_product_card_id                                  shop_product_name  \
# 0                  None  adidas-spezial-gazelle-spzl-dark-green-footwea...
# 1                  None  adidas-spezial-gazelle-spzl-night-indigo-suppl...
# 2                  None  adidas-spezial-samba-deco-spzl-brown-footwear-...
# 3                  None  adidas-spezial-samba-deco-spzl-core-black-luci...
# 4                  None  adidas-spezial-englewood-spzl-footwear-white-o...
# 5                  None  adidas-spezial-moscrop-spzl-ash-grey-four-grey...
# 6                  None  adidas-spezial-lawkholme-spzl-trace-khaki-wond...
# 7                  None  adidas-spezial-inverness-spzl-brown-brown-brow...
# 8                  None  adidas-spezial-hiaven-spzl-core-black-core-bla...
# 9                  None  adidas-originals-samba-og-cloud-white-core-bla...
# 10                 None  adidas-originals-handball-spezial-maroon-core-...
# ...

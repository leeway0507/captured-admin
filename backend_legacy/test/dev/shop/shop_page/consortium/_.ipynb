# %%
import pandas as pd

pd.read_parquet("./20240104-000118-product-id.parquet.gzip")
# Out:
#    shop_product_card_id product_id
# 0                 12345     B75806

# %%
pd.read_parquet("./20240104-000118-size.parquet.gzip")
# Out:
#     shop_product_card_id shop_product_size kor_product_size  available  \
# 0                  12345            UK 3.5              220       True
# 1                  12345              UK 4              225       True
# 2                  12345            UK 4.5              230       True
# 3                  12345              UK 5              235       True
# 4                  12345            UK 5.5              240       True
# 5                  12345              UK 6              245       True
# 6                  12345            UK 6.5              250       True
# 7                  12345              UK 7              255       True
# 8                  12345            UK 8.5              270       True
# 9                  12345              UK 9              275       True
# 10                 12345            UK 9.5              280       True
# 11                 12345             UK 10              285       True
# ...
